# %%
import sys
print(sys.executable)  # Path to the Python executable
print(sys.version)     # Python version
# Out:
# /usr/bin/python
# 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]

# %%
import cudf
print(cudf.Series([1, 2, 3]))
# Out:
# ---------------------------------------------------------------------------
# CudaSupportError                          Traceback (most recent call last)
# Cell In[14], line 2
#       1 import cudf
# ----> 2 print(cudf.Series([1, 2, 3]))
#
# File ~/.local/lib/python3.10/site-packages/cudf/utils/performance_tracking.py:51, in _performance_tracking.<locals>.wrapper(*args, **kwargs)
#      43 if nvtx.enabled():
#      44     stack.enter_context(
#      45         nvtx.annotate(
#      46             message=func.__qualname__,
#    (...)
#      49         )
#      50     )
# ---> 51 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/frame.py:1890, in Frame.__str__(self)
#    1888 @_performance_tracking
#    1889 def __str__(self):
# -> 1890     return repr(self)
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/series.py:1493, in Series.__repr__(self)
#    1484     output = pd_series.to_string(
#    1485         name=self.name,
#    1486         dtype=self.dtype,
#    (...)
#    1490         na_rep=str(cudf.NA),
#    1491     )
#    1492 else:
# -> 1493     output = repr(preprocess.to_pandas())
#    1495 lines = output.split("\n")
#    1496 if isinstance(preprocess.dtype, cudf.CategoricalDtype):
#
# File ~/.local/lib/python3.10/site-packages/cudf/utils/performance_tracking.py:51, in _performance_tracking.<locals>.wrapper(*args, **kwargs)
#      43 if nvtx.enabled():
#      44     stack.enter_context(
#      45         nvtx.annotate(
#      46             message=func.__qualname__,
#    (...)
#      49         )
#      50     )
# ---> 51 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/series.py:2086, in Series.to_pandas(self, index, nullable, arrow_type)
#    2083 else:
#    2084     index = None  # type: ignore[assignment]
#    2085 return pd.Series(
# -> 2086     self._column.to_pandas(nullable=nullable, arrow_type=arrow_type),
#    2087     index=index,
#    2088     name=self.name,
#    2089 )
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/numerical.py:711, in NumericalColumn.to_pandas(self, nullable, arrow_type)
#     709     return pd.Index(pandas_array, copy=False)
#     710 elif self.dtype.kind in set("iuf") and not self.has_nulls():
# --> 711     return pd.Index(self.values_host, copy=False)
#     712 else:
#     713     return super().to_pandas(nullable=nullable, arrow_type=arrow_type)
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/column.py:220, in ColumnBase.values_host(self)
#     217     raise ValueError("Column must have no nulls.")
#     219 with acquire_spill_lock():
# --> 220     return self.data_array_view(mode="read").copy_to_host()
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/column.py:135, in ColumnBase.data_array_view(self, mode)
#     133 else:
#     134     obj = None
# --> 135 return cuda.as_cuda_array(obj).view(self.dtype)
#
# File ~/.local/lib/python3.10/site-packages/numba_cuda/numba/cuda/api.py:76, in as_cuda_array(obj, sync)
#      74     raise TypeError("*obj* doesn't implement the cuda array interface.")
#      75 else:
# ---> 76     return from_cuda_array_interface(obj.__cuda_array_interface__,
#      77                                      owner=obj, sync=sync)
#
# File ~/.local/lib/python3.10/site-packages/numba_cuda/numba/cuda/cudadrv/devices.py:231, in require_context.<locals>._require_cuda_context(*args, **kws)
#     229 @functools.wraps(fn)
#     230 def _require_cuda_context(*args, **kws):
# --> 231     with _runtime.ensure_context():
#     232         return fn(*args, **kws)
#
# File /usr/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/.local/lib/python3.10/site-packages/numba_cuda/numba/cuda/cudadrv/devices.py:121, in _Runtime.ensure_context(self)
#     110 @contextmanager
#     111 def ensure_context(self):
#     112     """Ensure a CUDA context is available inside the context.
#     113
#     114     On entrance, queries the CUDA driver for an active CUDA context and
#    (...)
#     119     any top-level Numba CUDA API.
#     120     """
# --> 121     with driver.get_active_context():
#     122         oldctx = self._get_attached_context()
#     123         newctx = self.get_or_create_context(None)
#
# File ~/.local/lib/python3.10/site-packages/numba_cuda/numba/cuda/cudadrv/driver.py:472, in _ActiveContext.__enter__(self)
#     470 else:
#     471     hctx = drvapi.cu_context(0)
# --> 472     driver.cuCtxGetCurrent(byref(hctx))
#     473     hctx = hctx if hctx.value else None
#     475 if hctx is None:
#
# File ~/.local/lib/python3.10/site-packages/numba_cuda/numba/cuda/cudadrv/driver.py:272, in Driver.__getattr__(self, fname)
#     269 self.ensure_initialized()
#     271 if self.initialization_error is not None:
# --> 272     raise CudaSupportError("Error at driver init: \n%s:" %
#     273                            self.initialization_error)
#     275 if USE_NV_BINDING:
#     276     return self._cuda_python_wrap_fn(fname)
#
# CudaSupportError: Error at driver init:
# Call to cuInit results in CUDA_ERROR_NO_DEVICE (100):

# %%
import cudf
print(cudf.__version__)
print(cudf.Series([1, 2, 3]))
# Out:
# 24.12.00
# ---------------------------------------------------------------------------
# CudaSupportError                          Traceback (most recent call last)
# Cell In[12], line 3
#       1 import cudf
#       2 print(cudf.__version__)
# ----> 3 print(cudf.Series([1, 2, 3]))
#
# File ~/.local/lib/python3.10/site-packages/cudf/utils/performance_tracking.py:51, in _performance_tracking.<locals>.wrapper(*args, **kwargs)
#      43 if nvtx.enabled():
#      44     stack.enter_context(
#      45         nvtx.annotate(
#      46             message=func.__qualname__,
#    (...)
#      49         )
#      50     )
# ---> 51 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/frame.py:1890, in Frame.__str__(self)
#    1888 @_performance_tracking
#    1889 def __str__(self):
# -> 1890     return repr(self)
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/series.py:1493, in Series.__repr__(self)
#    1484     output = pd_series.to_string(
#    1485         name=self.name,
#    1486         dtype=self.dtype,
#    (...)
#    1490         na_rep=str(cudf.NA),
#    1491     )
#    1492 else:
# -> 1493     output = repr(preprocess.to_pandas())
#    1495 lines = output.split("\n")
#    1496 if isinstance(preprocess.dtype, cudf.CategoricalDtype):
#
# File ~/.local/lib/python3.10/site-packages/cudf/utils/performance_tracking.py:51, in _performance_tracking.<locals>.wrapper(*args, **kwargs)
#      43 if nvtx.enabled():
#      44     stack.enter_context(
#      45         nvtx.annotate(
#      46             message=func.__qualname__,
#    (...)
#      49         )
#      50     )
# ---> 51 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/series.py:2086, in Series.to_pandas(self, index, nullable, arrow_type)
#    2083 else:
#    2084     index = None  # type: ignore[assignment]
#    2085 return pd.Series(
# -> 2086     self._column.to_pandas(nullable=nullable, arrow_type=arrow_type),
#    2087     index=index,
#    2088     name=self.name,
#    2089 )
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/numerical.py:711, in NumericalColumn.to_pandas(self, nullable, arrow_type)
#     709     return pd.Index(pandas_array, copy=False)
#     710 elif self.dtype.kind in set("iuf") and not self.has_nulls():
# --> 711     return pd.Index(self.values_host, copy=False)
#     712 else:
#     713     return super().to_pandas(nullable=nullable, arrow_type=arrow_type)
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/column.py:220, in ColumnBase.values_host(self)
#     217     raise ValueError("Column must have no nulls.")
#     219 with acquire_spill_lock():
# --> 220     return self.data_array_view(mode="read").copy_to_host()
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/column.py:135, in ColumnBase.data_array_view(self, mode)
#     133 else:
#     134     obj = None
# --> 135 return cuda.as_cuda_array(obj).view(self.dtype)
#
# File ~/.local/lib/python3.10/site-packages/numba_cuda/numba/cuda/api.py:76, in as_cuda_array(obj, sync)
#      74     raise TypeError("*obj* doesn't implement the cuda array interface.")
#      75 else:
# ---> 76     return from_cuda_array_interface(obj.__cuda_array_interface__,
#      77                                      owner=obj, sync=sync)
#
# File ~/.local/lib/python3.10/site-packages/numba_cuda/numba/cuda/cudadrv/devices.py:231, in require_context.<locals>._require_cuda_context(*args, **kws)
#     229 @functools.wraps(fn)
#     230 def _require_cuda_context(*args, **kws):
# --> 231     with _runtime.ensure_context():
#     232         return fn(*args, **kws)
#
# File /usr/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/.local/lib/python3.10/site-packages/numba_cuda/numba/cuda/cudadrv/devices.py:121, in _Runtime.ensure_context(self)
#     110 @contextmanager
#     111 def ensure_context(self):
#     112     """Ensure a CUDA context is available inside the context.
#     113
#     114     On entrance, queries the CUDA driver for an active CUDA context and
#    (...)
#     119     any top-level Numba CUDA API.
#     120     """
# --> 121     with driver.get_active_context():
#     122         oldctx = self._get_attached_context()
#     123         newctx = self.get_or_create_context(None)
#
# File ~/.local/lib/python3.10/site-packages/numba_cuda/numba/cuda/cudadrv/driver.py:472, in _ActiveContext.__enter__(self)
#     470 else:
#     471     hctx = drvapi.cu_context(0)
# --> 472     driver.cuCtxGetCurrent(byref(hctx))
#     473     hctx = hctx if hctx.value else None
#     475 if hctx is None:
#
# File ~/.local/lib/python3.10/site-packages/numba_cuda/numba/cuda/cudadrv/driver.py:272, in Driver.__getattr__(self, fname)
#     269 self.ensure_initialized()
#     271 if self.initialization_error is not None:
# --> 272     raise CudaSupportError("Error at driver init: \n%s:" %
#     273                            self.initialization_error)
#     275 if USE_NV_BINDING:
#     276     return self._cuda_python_wrap_fn(fname)
#
# CudaSupportError: Error at driver init:
# Call to cuInit results in CUDA_ERROR_NO_DEVICE (100):
